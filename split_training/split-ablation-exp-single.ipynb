# %% [markdown]
# # Split training ablation experiment
#
# Compares graph recovery between models that are identical in every way — same data, same initial weights, same hyperparameters — differing only in whether they use the sequence-split approximation during EM/Viterbi training.
#
# Pairs compared:
# - `cscg_se` vs `cscg_se_split_base` (soft-evidence models)
# - `cscg_he` vs `cscg_he_split_base` (hard-evidence models)
#
# The `*_split_base` variants inherit from the base (non-opt) models, so the **only** algorithmic difference is the boundary approximation: each sequence segment restarts forward/backward messages from the prior `pi` rather than from the true forward message at the segment boundary.

# %% [markdown]
# ## Imports

# %%
import os
import jax
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.rcParams.update({'font.size': 14})

from cscg import cscg_he_split as cscg
from cscg import utils

# using only gpu0
# os.environ["CUDA_VISIBLE_DEVICES"]='0'

print(f'JAX devices: {jax.device_count()}')
# Out:
# JAX devices: 8

# %% [markdown]
# ## Grid world

# %%
n_rows, n_cols = 20, 20  # grid dimensions (rows × cols)

def build_grid(n_rows, n_cols):
    """Build an n_rows×n_cols color-ID grid."""
    grid = np.zeros((n_rows, n_cols), dtype=int)
    grid[0, 1:-1] = 1      # top edge
    grid[-1, 1:-1] = 2     # bottom edge
    grid[1:-1, 0] = 3      # left edge
    grid[1:-1, -1] = 4     # right edge
    grid[0, 0] = 5         # top-left corner
    grid[-1, 0] = 6        # bottom-left corner
    grid[0, -1] = 7        # top-right corner
    grid[-1, -1] = 8       # bottom-right corner
    return grid

grid = build_grid(n_rows, n_cols)

obs_names = [
    'Interior', 'Top edge', 'Bottom edge', 'Left edge', 'Right edge',
    'TL corner', 'BL corner', 'TR corner', 'BR corner',
]

fig, ax = plt.subplots(figsize=(8, 5))
cmap_grid = plt.cm.get_cmap('tab10', 9)
im = ax.imshow(grid, cmap=cmap_grid, vmin=-0.5, vmax=8.5)
for r in range(n_rows):
    for c in range(n_cols):
        ax.text(c, r, str(grid[r, c]), ha='center', va='center', fontsize=10, color='k')
ax.set_title(f'{n_rows}×{n_cols} grid — color IDs')
ax.set_xticks([])
ax.set_yticks([])
patches = [mpatches.Patch(color=cmap_grid(i / 8), label=f'{i}: {obs_names[i]}') for i in range(9)]
ax.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3398924/3384138739.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap_grid = plt.cm.get_cmap('tab10', 9)

# %% [markdown]
# ## Generate training data

# %%
def generate_random_walk(grid, length, seed=0):
    """Random walk on grid. Returns (actions, observations, positions).

    Actions: 0=N, 1=E, 2=S, 3=W.
    action[t] is the action taken at step t, causing the transition to step t+1.
    The final action is a dummy (0).
    """
    rng = np.random.default_rng(seed)
    n_rows, n_cols = grid.shape
    deltas = [(-1, 0), (0, 1), (1, 0), (0, -1)]  # N, E, S, W

    r, c = n_rows // 2, n_cols // 2  # start at center
    observations = np.zeros(length, dtype=int)
    actions = np.zeros(length, dtype=int)
    positions = np.zeros((length, 2), dtype=int)

    observations[0] = grid[r, c]
    positions[0] = (r, c)

    for t in range(length - 1):
        a = int(rng.integers(0, 4))
        dr, dc = deltas[a]
        nr, nc = r + dr, c + dc
        if 0 <= nr < n_rows and 0 <= nc < n_cols:
            r, c = nr, nc
        actions[t] = a
        observations[t + 1] = grid[r, c]
        positions[t + 1] = (r, c)

    return actions, observations, positions

length = 1_000_000
a, x, pos_walk = generate_random_walk(grid, length, seed=42)

print(f'Sequence length: {length:,}')
print(f'Unique observations: {np.unique(x)}')
visited = set(map(tuple, pos_walk))
print(f'Grid cells visited: {len(visited)} / {n_rows * n_cols}')
# Out:
# Sequence length: 1,500,000
# Unique observations: [0 1 2 3 4 5 6 7 8]
# Grid cells visited: 400 / 400

# %% [markdown]
# ## Model configuration
#
# All four models share the same:
# - `n_clones` (clone allocation)
# - `seed=0` → identical initial counts matrix
# - `pseudocount`
# - Training sequence `x_train`, `a_train`
#
# The sequence length `T` is trimmed to be divisible by `n_devices × num_splits` so both split and non-split models (which only require divisibility by `n_devices`) can use the same data.

# %%
n_obs = int(grid.max()) + 1
n_clones = 10 * np.array([(grid == i).sum() for i in range(n_obs)], dtype=int)
print('n_clones:')
for i, (name, nc) in enumerate(zip(obs_names, n_clones)):
    print(f'  obs {i} ({name}): {nc}')
print(f'Total states: {n_clones.sum()} (grid cells: {n_rows * n_cols})')

num_splits = 128
n_devices = jax.device_count()
print("Devices:", n_devices)
T = (length // (n_devices * num_splits)) * (n_devices * num_splits)
x_train, a_train = x[:T], a[:T]
pos_train = pos_walk[:T]
print(f'\nTraining sequence length: {T:,} (devices={n_devices}, num_splits={num_splits})')

pseudocount = 5e-4
SEED = 0
N_EM_ITER = 2000
N_VIT_ITER = 20
# Out:
# n_clones:
#   obs 0 (Interior): 3240
#   obs 1 (Top edge): 180
#   obs 2 (Bottom edge): 180
#   obs 3 (Left edge): 180
#   obs 4 (Right edge): 180
#   obs 5 (TL corner): 10
#   obs 6 (BL corner): 10
#   obs 7 (TR corner): 10
#   obs 8 (BR corner): 10
# Total states: 4000 (grid cells: 400)
# Devices: 8
#
# Training sequence length: 1,499,136 (devices=8, num_splits=128)

# %% [markdown]
# ## Instantiate models
#
# All four models are created with `seed=0`, giving them the same random initial counts matrix. We assert this below.

# %%
model_he_split = cscg.CSCG(
    n_clones=n_clones, pseudocount=pseudocount, n_actions=4,
    seed=SEED, batched=True, use_bfloat16=False, num_splits=num_splits,
)



models = [
    ('HE (split)',       model_he_split),
]

for label, m in models:
    print(f'{label}: implementation={m.implementation}, states={m.num_states}')
# Out:
# HE (split): implementation=he_split_128, states=4000

# %% [markdown]
# ## Train all models
#
# Each model runs EM training followed by Viterbi training using the exact same sequence.

# %%
convergence = {}

for label, m in models:
    print(f'\n=== Training {label} ===')
    conv_em = m.learn_em_transition(
        observations=x_train, actions=a_train, n_iter=N_EM_ITER, term_early=True,
    )
    conv_vit = m.learn_viterbi_transition(
        observations=x_train, actions=a_train, n_iter=N_VIT_ITER,
    )
    convergence[label] = (conv_em, conv_vit)
    print(f'  EM iters: {len(conv_em)}, final bps: {conv_em[-1]:.4f}')
    print(f'  Viterbi iters: {len(conv_vit)}, final bps: {conv_vit[-1]:.4f}')
# Out:
# === Training HE (split) ===
#   0%|          | 0/2000 [00:00<?, ?it/s]
# 2026-04-07 16:21:29.004257: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3022] Can't reduce memory use below 53.81GiB (57780138958 bytes) by rematerialization; only reduced to 108.30GiB (116288423244 bytes), down from 108.30GiB (116290082124 bytes) originally
# 2026-04-07 16:21:39.532011: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_4_bfc) ran out of memory trying to allocate 108.03GiB (rounded to 116000522752)requested by op
# 2026-04-07 16:21:39.532078: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ******______________________________________________________________________________________________
# E0407 16:21:39.532098 3399336 pjrt_stream_executor_client.cc:2917] Execution of replica 4 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes. [tf-allocator-allocation-error='']
# 2026-04-07 16:21:39.532852: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 108.03GiB (rounded to 116000522752)requested by op
# 2026-04-07 16:21:39.532931: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ******______________________________________________________________________________________________
# E0407 16:21:39.532947 3399324 pjrt_stream_executor_client.cc:2917] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes. [tf-allocator-allocation-error='']
# 2026-04-07 16:21:39.533214: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_3_bfc) ran out of memory trying to allocate 108.03GiB (rounded to 116000522752)requested by op
# 2026-04-07 16:21:39.533282: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ******______________________________________________________________________________________________
# E0407 16:21:39.533289 3399333 pjrt_stream_executor_client.cc:2917] Execution of replica 3 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes. [tf-allocator-allocation-error='']
# 2026-04-07 16:21:39.583787: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_1_bfc) ran out of memory trying to allocate 108.03GiB (rounded to 116000522752)requested by op
# 2026-04-07 16:21:39.583856: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ******______________________________________________________________________________________________
# E0407 16:21:39.583868 3399327 pjrt_stream_executor_client.cc:2917] Execution of replica 1 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes. [tf-allocator-allocation-error='']
# 2026-04-07 16:21:39.584198: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_2_bfc) ran out of memory trying to allocate 108.03GiB (rounded to 116000522752)requested by op
# 2026-04-07 16:21:39.584258: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ******______________________________________________________________________________________________
# E0407 16:21:39.584267 3399330 pjrt_stream_executor_client.cc:2917] Execution of replica 2 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes. [tf-allocator-allocation-error='']
# 2026-04-07 16:21:39.614678: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_7_bfc) ran out of memory trying to allocate 108.03GiB (rounded to 116000522752)requested by op
# 2026-04-07 16:21:39.614745: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ******______________________________________________________________________________________________
# E0407 16:21:39.614756 3399345 pjrt_stream_executor_client.cc:2917] Execution of replica 7 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes. [tf-allocator-allocation-error='']
# 2026-04-07 16:21:39.615338: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_6_bfc) ran out of memory trying to allocate 108.03GiB (rounded to 116000522752)requested by op
# 2026-04-07 16:21:39.615411: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ******______________________________________________________________________________________________
# E0407 16:21:39.615424 3399342 pjrt_stream_executor_client.cc:2917] Execution of replica 6 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes. [tf-allocator-allocation-error='']
# 2026-04-07 16:21:39.615889: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_5_bfc) ran out of memory trying to allocate 108.03GiB (rounded to 116000522752)requested by op
# 2026-04-07 16:21:39.615963: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] ******______________________________________________________________________________________________
# E0407 16:21:39.615979 3399339 pjrt_stream_executor_client.cc:2917] Execution of replica 5 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes. [tf-allocator-allocation-error='']
#   0%|          | 0/2000 [00:19<?, ?it/s]
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[6], line 5
#       3 for label, m in models:
#       4     print(f'\n=== Training {label} ===')
# ----> 5     conv_em = m.learn_em_transition(
#       6         observations=x_train, actions=a_train, n_iter=N_EM_ITER, term_early=True,
#       7     )
#       8     conv_vit = m.learn_viterbi_transition(
#       9         observations=x_train, actions=a_train, n_iter=N_VIT_ITER,
#      10     )
#      11     convergence[label] = (conv_em, conv_vit)
#
# File ~/space_is_a_latent_sequence/cscg/cscg_he_split.py:571, in CSCG.learn_em_transition(self, observations, actions, emission_matrix, n_iter, term_early)
#     560 log2_lik, mess_fwd = self._forward(
#     561     self._transition_matrix,
#     562     self._pi_states,
#    (...)
#     567     self._max_clones,
#     568 )
#     570 # compute backward messages and update counts matrix (fused)  # CHANGED
# --> 571 self._counts_matrix = self._update_transition_counts(
#     572     self._transition_matrix,
#     573     mess_fwd,
#     574     observations,
#     575     actions,
#     576     self._obs_to_state_start_idx,
#     577     self._masked_multiplier,
#     578     self._max_clones,
#     579 )
#     581 # M step ----
#     582 self._transition_matrix = self._update_transition_matrix(
#     583     self._counts_matrix, self._pseudocount
#     584 )
#
#     [... skipping hidden 3 frame]
#
# File ~/space_is_a_latent_sequence/venv/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1306, in ExecuteReplicated.__call__(self, *args)
#    1304   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1305 else:
# -> 1306   results = self.xla_executable.execute_sharded(input_bufs)
#    1308 if dispatch.needs_check_special():
#    1309   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 116000522576 bytes.: while running replica 0 and partition 0 of a replicated computation (other replicas may have failed as well).

# %% [markdown]
# ## Convergence curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

colors = ['tab:blue', 'tab:cyan', 'tab:red', 'tab:orange']
linestyles = ['-', '--', '-', '--']

for (label, _), color, ls in zip(models, colors, linestyles):
    conv_em, conv_vit = convergence[label]
    axes[0].plot(conv_em, label=label, color=color, linestyle=ls)
    axes[1].plot(conv_vit, label=label, color=color, linestyle=ls)

axes[0].set_xlabel('EM iteration')
axes[0].set_ylabel('bps')
axes[0].set_title('EM convergence')
axes[0].legend()

axes[1].set_xlabel('Viterbi iteration')
axes[1].set_ylabel('bps')
axes[1].set_title('Viterbi convergence')
axes[1].legend()

plt.suptitle('Training convergence — split vs no-split ablation', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Decode and build position maps

# %%
def decode_and_build_pos(model):
    states = np.array(model.decode(observations=x_train, actions=a_train)[1])
    state_pos_counts = {}
    for t, s in enumerate(states):
        rc = (int(pos_train[t, 0]), int(pos_train[t, 1]))
        if s not in state_pos_counts:
            state_pos_counts[s] = {}
        state_pos_counts[s][rc] = state_pos_counts[s].get(rc, 0) + 1
    state_to_pos = {s: max(cnt, key=cnt.get) for s, cnt in state_pos_counts.items()}
    unique_states = np.unique(states)
    pos_graph = {
        i: (state_to_pos[s][1], -state_to_pos[s][0])
        for i, s in enumerate(unique_states)
    }
    return states, pos_graph

results = {}
for label, m in models:
    states, pos_graph = decode_and_build_pos(m)
    results[label] = (states, pos_graph)
    print(f'{label}: {len(np.unique(states))} unique decoded states (grid cells: {n_rows * n_cols})')
# Out:
# HE (split): 130 unique decoded states (grid cells: 99)

# %% [markdown]
# ## Compare recovered graphs
#
# 2×2 grid: rows = SE / HE, columns = no-split / split.

# %%
fig, axes = plt.subplots(1, 1, figsize=(6, 6))

layout = [
    [('HE (split)', model_he_split)],
]


ax = axes
states, pos_graph = results[label]

ax.imshow(
    grid, cmap=cmap_grid, vmin=-0.5, vmax=8.5, alpha=0.15,
    extent=[-0.5, n_cols - 0.5, -(n_rows - 0.5), 0.5],
)
utils.plot_graph(
    m.counts_matrix,
    states,
    n_clones,
    x_train.max(),
    ax=ax,
    pos=pos_graph,
    node_size=350,
    threshold=0.0,
    cmap='tab10',
)
ax.set_xlim(-0.5, n_cols - 0.5)
ax.set_ylim(-(n_rows - 0.5), 0.5)
ax.set_title(label, fontsize=14)
ax.set_xticks([])
ax.set_yticks([])
ax.set_aspect('equal')

patches = [mpatches.Patch(color=cmap_grid(i / 8), label=f'{i}: {obs_names[i]}') for i in range(9)]

plt.suptitle(
    f'Split ablation — recovered transition graphs on {n_rows}×{n_cols} colored grid\n'
    f'(same data, same seed, only split differs)',
    fontsize=15,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary statistics

# %%
print(f'Ground truth: {n_rows * n_cols} grid cells, {n_clones.sum()} total clones')
print()
print(f'{"Model":<20} {"Decoded states":>15} {"EM iters":>10} {"EM bps":>10} {"Vit iters":>10} {"Vit bps":>10}')
print('-' * 80)
for label, m in models:
    states, _ = results[label]
    conv_em, conv_vit = convergence[label]
    print(
        f'{label:<20} {len(np.unique(states)):>15} '
        f'{len(conv_em):>10} {conv_em[-1]:>10.4f} '
        f'{len(conv_vit):>10} {conv_vit[-1]:>10.4f}'
    )
# Out:
# Ground truth: 99 grid cells, 990 total clones
#
# Model                 Decoded states   EM iters     EM bps  Vit iters    Vit bps
# --------------------------------------------------------------------------------
# HE (split)                       130        750     0.0396          5     0.0064
